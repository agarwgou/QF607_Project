# %%
from source import *

# %% [markdown]
# We test with no smile case first. In the calibration error report, we are showing the error in basis points -- 0.01% with respect to 1 notional.

# %%
S, r, q = 1.25805, 0.01, 0.0
iv = createTestImpliedVol(S, r, q, sc = 0.0, smileInterpMethod='CUBICSPLINE')
plotTestImpliedVolSurface(S, r, q, iv)
pdeCalibReport(S, r, q, iv)

# %% [markdown]
# Then test smile case with CubicSpline, with a mild smile (tuned by the coeffiicent sc)

# %%
iv = createTestImpliedVol(S, r, q, sc = 0.5, smileInterpMethod='CUBICSPLINE')
plotTestImpliedVolSurface(S, r, q, iv)
pdeCalibReport(S, r, q, iv)

# %% [markdown]
# Then test smile case with CubicSpline, with a the input smile (sc = 1.0). It can be seen that the short end low strike region has some smile arbitrage. The calibration errors become larger.

# %%
iv = createTestImpliedVol(S, r, q, sc = 1.0, smileInterpMethod='CUBICSPLINE')
plotTestImpliedVolSurface(S, r, q, iv)
pdeCalibReport(S, r, q, iv)

# %% [markdown]
# ***
# ### Your test cases with SmileAF

# %%
iv = createTestImpliedVol(S, r, q, sc = 1.0, smileInterpMethod='AF')
plotTestImpliedVolSurface(S, r, q, iv)
pdeCalibReport(S, r, q, iv)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 iv = createTestImpliedVol(S, r, q, sc = 1.0, smileInterpMethod='AF')
#       2 plotTestImpliedVolSurface(S, r, q, iv)
#       3 pdeCalibReport(S, r, q, iv)
#
# File ~/SMU_MQF/QF607_NMe/Project/source/report.py:23, in createTestImpliedVol(S, r, q, sc, smileInterpMethod)
#      21 bf10s = [0.0050, 0.0050, 0.0067, 0.0088, 0.0111, 0.0144, 0.0190, 0.0201, 0.0204, 0.0190, 0.0186, 0.0172, 0.0155, 0.0148]
#      22 rr10s = [-0.0111, -0.0187, -0.0248, -0.0315, -0.0439, -0.0518, -0.0627, -0.0652, -0.0662, -0.0646, -0.0636, -0.0627, -0.0627]
# ---> 23 smiles = [smileFromMarks(pillars[i], S, r, q, atmvols[i], bf25s[i]*sc, rr25s[i]*sc, bf10s[i]*sc, rr10s[i]*sc, smileInterpMethod) for i in range(len(pillars))]
#      24 return ImpliedVol(pillars, smiles)
#
# File ~/SMU_MQF/QF607_NMe/Project/source/report.py:23, in <listcomp>(.0)
#      21 bf10s = [0.0050, 0.0050, 0.0067, 0.0088, 0.0111, 0.0144, 0.0190, 0.0201, 0.0204, 0.0190, 0.0186, 0.0172, 0.0155, 0.0148]
#      22 rr10s = [-0.0111, -0.0187, -0.0248, -0.0315, -0.0439, -0.0518, -0.0627, -0.0652, -0.0662, -0.0646, -0.0636, -0.0627, -0.0627]
# ---> 23 smiles = [smileFromMarks(pillars[i], S, r, q, atmvols[i], bf25s[i]*sc, rr25s[i]*sc, bf10s[i]*sc, rr10s[i]*sc, smileInterpMethod) for i in range(len(pillars))]
#      24 return ImpliedVol(pillars, smiles)
#
# File ~/SMU_MQF/QF607_NMe/Project/source/project_code.py:107, in smileFromMarks(T, S, r, q, atmvol, bf25, rr25, bf10, rr10, smileInterpMethod)
#     105     return SmileCubicSpline(ks, [p10, p25, atmvol, c25, c10])
#     106 elif smileInterpMethod == "AF":
# --> 107     return SmileAF(ks, [p10, p25, atmvol, c25, c10], T)
#
# File ~/SMU_MQF/QF607_NMe/Project/source/project_code.py:45, in SmileAF.__init__(self, strikes, vols, T)
#      43     f = lambda v: implyVol(self.ks[i], prc, v)
#      44     a, b = 1e-8, 10
# ---> 45     vs[i - (khmin-1) + 1] = optimize.brentq(f, a, b)
#      46     kks[i - (khmin-1) + 1] = self.ks[i]
#      47 kks[0] = kmin
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/optimize/_zeros_py.py:784, in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     782 if rtol < _rtol:
#     783     raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 784 r = _zeros._brentq(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     785 return results_c(full_output, r)
#
# ValueError: f(a) and f(b) must have different signs
